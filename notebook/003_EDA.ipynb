# %% [markdown]
# ## about object_collection

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
out_dir = '../output/'
data = "../datasets/"

# %%
train_df = pd.read_csv(data + "train.csv")
test_df = pd.read_csv(data + "test.csv")

# %%
def show_me_med(df):
    print('mean :' + str(df.mean()) + '\nmedian: ' + str(df.median()))

# %%
train_df
# Out:
#               object_id         art_series_id                        title  \
# 0  0011d6be41612ec9eae3  93c092ba70beab248f31        The Avenue of Birches
# 1  0012765f7a97ccc3e9e9  95c14fb11c54281ad7e0              Struik in bloei
# 2  0017be8caa87206532cb  4c406890d208fe01f8fb        Portret van een vrouw
# 3  00181d86ff1a7b95864e  fa0891535500a4973db2             A St Bernard Dog
# 4  001c52ae28ec106d9cd5  8065ed5063c5887e677d  Woelige zee met zeilschepen
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2     Portret van eenvrouw, zittend naast een tafel.
# 3  Een sint-bernardshond, staand in een landschap...
# 4                       Woelige zee met zeilschepen.
#
#                                           long_title   principal_maker  \
# 0   The Avenue of Birches, Jan Hackaert, 1660 - 1685      Jan Hackaert
# ...

# %%
obj_collection_df = pd.read_csv(data+'object_collection.csv')

# %%
obj_dup = obj_collection_df[obj_collection_df.duplicated(subset='object_id')]

# %%
obj_dup_df = train_df[train_df['object_id'].isin(obj_dup['object_id'])]

# %%
show_me_med(obj_dup_df['likes'])
# Out:
# mean :126.0
# median: 11.5

# %%
obj_collection_df
# Out:
#                   object_id       name
# 0      001020bd00b149970f78  paintings
# 1      0011d6be41612ec9eae3  paintings
# 2      00133be3ff222c9b74b0     prints
# 3      00181d86ff1a7b95864e  paintings
# 4      001c52ae28ec106d9cd5  paintings
# ...                     ...        ...
# 14205  ffe7e1649e805918e42c     prints
# 14206  ffee34705ea44e1a0f79     prints
# 14207  ffefbe1faf771aa4f790     prints
# 14208  fff08e76cbb969eaddc7     prints
# 14209  fff1d87d79953ddab2c6  paintings
#
# [14210 rows x 2 columns]

# %%
obj_collection_df[obj_dup]
# Out:
#                   object_id                 name
# 380    067f74cd4be8b56771f3            paintings
# 720    0c49601da36b1ed90f86                paper
# 763    0d1eb2fe8c655bdf8587               prints
# 813    0e31e8b71799cb12aa5d                paper
# 1119   13888e5bc0ff6748323d                paper
# 1614   1c7270562da80b1974cf               prints
# 1971   22a748435c25765774f7      Navy Model Room
# 2341   2923964baf35f2efdf54                paper
# 2427   2aa659df8674717ef06a  musical instruments
# 2644   2e4522122d5735925ed2      Navy Model Room
# 2801   316a60e1137da9718d74  musical instruments
# 3237   399c3e17e40f3f014041               prints
# 3500   3e4cb476d5242596c4bb               prints
# 3686   41f57ebe0a29611df351               prints
# 4779   55d24095d80c401f81a9                paper
# 5237   5e856154a5ac385cd43b                paper
# 5738   67860974de09200b24fa      Navy Model Room
# 5825   691d9bee56f1e2c3c88d               prints
# ...

# %%
music = obj_collection_df['object_id'][obj_collection_df['name'] =='musical instruments']

# %%
music
# Out:
# 379     067f74cd4be8b56771f3
# 2427    2aa659df8674717ef06a
# 2801    316a60e1137da9718d74
# 6791    79b5e44e2adcce608b34
# Name: object_id, dtype: object

# %%
music
# Out:
# 379     067f74cd4be8b56771f3
# 2427    2aa659df8674717ef06a
# 2801    316a60e1137da9718d74
# 6791    79b5e44e2adcce608b34
# Name: object_id, dtype: object

# %%
non_collect_df = train_df[~train_df['object_id'].isin(obj_collection_df['object_id'])]
collect_df = train_df[train_df['object_id'].isin(obj_collection_df['object_id'])]

# %%
non_collect_df['likes'].median()
# Out:
# 1.0

# %%
non_collect_df['likes'].mean()
# Out:
# 9.894297352342159

# %%
collect_df['likes'].median()
# Out:
# 5.0

# %%
collect_df['likes'].mean()
# Out:
# 131.61045531197303

# %%
plt.plot(train_df['likes'])

# %%
_x = np.arange(min(non_collent_df['likes']),max(non_collent_df['likes']))

# %%
plt.plot(non_collent_df['likes'])

# %%
test_df[test_df['object_id'].isin(music)]
# Out:
#                  object_id         art_series_id                 title  \
# 319   067f74cd4be8b56771f3  fd09200b5db257324c0f  Lid of a harpsichord
# 2081  2aa659df8674717ef06a  17703e547e7825c1ad1d  Lid of a harpsichord
#
#                                             description  \
# 319   Feestmaal in de tuin van een kasteel aan de oe...
# 2081  Twee voorstellingen: op de deksel van een clav...
#
#                                              long_title       principal_maker  \
# 319            Lid of a harpsichord, Philip Schey, 1626          Philip Schey
# 2081  Lid of a harpsichord, Gerard van der Horst (co...  Gerard van der Horst
#
#      principal_or_first_maker             sub_title copyright_holder  \
# 319              Philip Schey    h 79.8cm × w 169cm              NaN
# 2081     Gerard van der Horst  h 84.8cm × w 161.8cm              NaN
#
#                                              more_title acquisition_method  \
# ...
